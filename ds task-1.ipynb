# %%
import requests
import pandas as pd

# %%
url='https://data.binance.com/api/v3/ticker/24hr'

# %%
response=requests.get(url)

# %%
if response.status_code==200:
    data=response.json()
    df=pd.DataFrame(data)
    csv_filename="binance_ticker_data.csv"
    df.to_csv(csv_filename,index=False)
    print(f"Csv dataset saved as{csv_filename}")
else:
    print(f"Failed data. Status code: {response.status_code}")
# Out:
# Csv dataset saved asbinance_ticker_data.csv

# %%
df=pd.read_csv("binance_ticker_data.csv")
df
# Out:
#          symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0        ETHBTC     0.000070               0.113          0.062167
# 1        LTCBTC     0.000000               0.000          0.002445
# 2        BNBBTC    -0.000023              -0.287          0.007970
# 3        NEOBTC     0.000000               0.000          0.000271
# 4       QTUMETH    -0.000008              -0.598          0.001329
# ...         ...          ...                 ...               ...
# 2297    ARKUSDT    -0.017600              -3.385          0.514552
# 2298  CREAMUSDT    -0.210000              -1.160         18.093679
# 2299    GFTUSDT     0.000400               1.450          0.028004
# 2300     IQUSDT    -0.000010              -0.205          0.004868
# 2301    USDTVAI     0.004000               0.397          1.007655
#
#       prevClosePrice  lastPrice      lastQty   bidPrice      bidQty  \
# 0           0.062080   0.062140       4.5422   0.062140     46.2754
# ...
